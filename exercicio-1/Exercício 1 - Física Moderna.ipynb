# %% [markdown]
# # Exercício 1 - Física Moderna (ANP)
# #### Aluno: João Vitor Amorim
#
# Neste exercício devemos representar os estados |0>, |1>, (|0> + |1>)/sqrt(2), (|0> - |1>)/sqrt(2), (|0> + i*|1>)/sqrt(2) e (|0> - i*|1>)/sqrt(2) na Esfera de Bloch. Esses estados representam os pontos de interseção da Esfera de Bloch com os eixos coordenados.
#
# Dados iniciais auxiliares:
#
# <img src="img/formula.png">

# %% [markdown]
# Importando as bibliotecas necessárias para a plotagem gráfica da Esfera de Bloch usando o Qiskit:

# %%
# %matplotlib inline
from qiskit import *
import matplotlib
from qiskit.visualization import plot_bloch_vector

# %% [markdown]
# ---
#
# #### - Estado |0> :
#
# <img src="img/01.jpg" width="50%">

# %%
plot_bloch_vector((0,0,1))

# %% [markdown]
# ---
#
# #### - Estado |1> :
#
# <img src="img/02.jpg" width="50%">

# %%
plot_bloch_vector((0,0,-1))

# %% [markdown]
# ---
#
# #### - Estado (|0> + |1>)/sqrt(2) :
#
# <img src="img/03.jpg" width="50%">

# %%
plot_bloch_vector((1,0,0))

# %% [markdown]
# ---
#
# #### - Estado (|0> - |1>)/sqrt(2) :
#
# <img src="img/04.jpg" width="50%">

# %%
plot_bloch_vector((-1,0,0))

# %% [markdown]
# ---
#
# #### - Estado (|0> + i * |1>)/sqrt(2) :
#
# <img src="img/05.jpg" width="50%">

# %%
plot_bloch_vector((0,1,0))

# %% [markdown]
# ---
#
# #### - Estado (|0> - i*|1>)/sqrt(2) :
#
# <img src="img/06.jpg" width="50%">

# %%
plot_bloch_vector((0,-1,0))

# %% [markdown]
# ---
#
# #### - Esfera com todos os estados representados:
#
# <img src="img/esfera.jpg" width="65%">
